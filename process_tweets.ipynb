# %%
import pandas as pd

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
ty = pd.read_csv("/Users/dimmehal/Desktop/work/Twitter/Bitcoin_tweets.csv", nrows=20)

# %%
y
# Out:
#                                    user_name    user_location  \
# 0                              DeSota Wilson      Atlanta, GA
# 1                                   CryptoND              NaN
# 2                                  Tdlmatias  London, England
# 3                       Crypto is the future              NaN
# 4   Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# 5                        ZerrBenz™ ⚔ ✪ 20732    Bkk, Thailand
# 6                                Bitcoin-Bot     Florida, USA
# 7                     Cryptocurrencies / EUR              NaN
# 8                                    Mikcoin              NaN
# 9                              DeSota Wilson      Atlanta, GA
# 10     @massumeh18 #RefinedWarrior #Activist             NOVA
# 11                             BittrexPrices              NaN
# 12                                   CPUcoin   Cayman Islands
# 13                           One Perspective     Market Place
# ...

# %%
z = pd.read_csv("/Users/dimmehal/PycharmProjects/twitter_sentiment/tweets_3.csv", nrows=20)

# %%
z
# Out:
#    https://twitter.com/Neloangelo314/status/1421621692032602117  \
# 0   https://twitter.com/CryptoWatchBot/status/1421...
# 1   https://twitter.com/WhaleTrades/status/1421621...
# 2   https://twitter.com/WatchinWhales/status/14216...
# 3   https://twitter.com/HobaBot/status/14216216589...
# 4   https://twitter.com/AnthonyDessauer/status/142...
# 5   https://twitter.com/WhaleTrades/status/1421621...
# 6   https://twitter.com/griffinartworld/status/142...
# 7   https://twitter.com/WhaleTrades/status/1421621...
# 8   https://twitter.com/Crablinski/status/14216216...
# 9   https://twitter.com/WhaleTrades/status/1421621...
# 10  https://twitter.com/WhaleTrades/status/1421621...
# 11  https://twitter.com/Mc_frittz/status/142162156...
# 12  https://twitter.com/spinte8/status/14216214978...
# 13  https://twitter.com/Bitcoin8star/status/142162...
# 14  https://twitter.com/bitcoin_tesla/status/14216...
# 15  https://twitter.com/RixxTech/status/1421621474...
# ...

# %%
btc_prices = pd.read_parquet("/Users/dimmehal/PycharmProjects/twitter_sentiment/data/BTC-USDT.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m1/8wsbp1px1rn5_gc72hrvpkbr0000gn/T/ipykernel_82999/4076303526.py in <module>
# ----> 1 btc_prices = pd.read_parquet("/Users/dimmehal/PycharmProjects/twitter_sentiment/data/BTC-USDT.parquet")
#       2
#
# NameError: name 'pd' is not defined

# %%
btc_prices.to_csv("/Users/dimmehal/PycharmProjects/twitter_sentiment/data/btc_prices.csv")

# %%
import matplotlib.pyplot as plt


price_values = btc_prices["open"].values
dates = btc_prices.index.values

# %%
plt.plot(dates, price_values)
#plt.yscale('log')

# %%
btc_prices_filtered = btc_prices.loc['2021-07-01':'2021-09-01']
btc_prices_filtered_f = btc_prices_filtered.iloc[::60, :]

# %%
price_values = btc_prices_filtered_f["open"].values
dates = btc_prices_filtered_f.index.values
plt.plot(dates, price_values)
plt.yscale('log')

# %%
btc_prices_filtered_f
# Out:
#                              open          high           low         close  \
# open_time
# 2021-07-01 00:00:00  35045.000000  35057.570312  34966.089844  34980.468750
# 2021-07-01 01:00:00  34727.828125  34750.851562  34716.128906  34721.738281
# 2021-07-01 02:00:00  34936.429688  34966.531250  34900.000000  34900.050781
# 2021-07-01 03:00:00  34299.578125  34357.000000  34295.000000  34351.000000
# 2021-07-01 04:00:00  34120.011719  34149.921875  34105.000000  34122.929688
# ...                           ...           ...           ...           ...
# 2021-08-06 19:00:00  42792.949219  42865.398438  42792.941406  42835.750000
# 2021-08-06 20:00:00  42901.179688  42950.000000  42900.171875  42920.949219
# 2021-08-06 21:00:00  42702.820312  42750.000000  42702.808594  42745.011719
# 2021-08-06 22:00:00  42423.871094  42540.980469  42423.871094  42524.921875
# 2021-08-06 23:00:00  42780.070312  42789.000000  42718.710938  42726.539062
#
# ...

# %%
y
# Out:
#                                    user_name    user_location  \
# 0                              DeSota Wilson      Atlanta, GA
# 1                                   CryptoND              NaN
# 2                                  Tdlmatias  London, England
# 3                       Crypto is the future              NaN
# 4   Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# 5                        ZerrBenz™ ⚔ ✪ 20732    Bkk, Thailand
# 6                                Bitcoin-Bot     Florida, USA
# 7                     Cryptocurrencies / EUR              NaN
# 8                                    Mikcoin              NaN
# 9                              DeSota Wilson      Atlanta, GA
# 10     @massumeh18 #RefinedWarrior #Activist             NOVA
# 11                             BittrexPrices              NaN
# 12                                   CPUcoin   Cayman Islands
# 13                           One Perspective     Market Place
# ...

# %%
SIA = SentimentIntensityAnalyzer()

# %%
y['sent_value'] = y.apply(lambda x: SIA.polarity_scores(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/m1/8wsbp1px1rn5_gc72hrvpkbr0000gn/T/ipykernel_3944/1651997013.py in <module>
# ----> 1 y['sent_value'] = y.apply(lambda x: SIA.polarity_scores(x))
#
# ~/anaconda3/envs/twitter_sentiment/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8734             kwargs=kwargs,
#    8735         )
# -> 8736         return op.apply()
#    8737
#    8738     def applymap(
#
# ~/anaconda3/envs/twitter_sentiment/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/envs/twitter_sentiment/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
# ...

# %%
y
# Out:
#                                    user_name    user_location  \
# 0                              DeSota Wilson      Atlanta, GA
# 1                                   CryptoND              NaN
# 2                                  Tdlmatias  London, England
# 3                       Crypto is the future              NaN
# 4   Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# 5                        ZerrBenz™ ⚔ ✪ 20732    Bkk, Thailand
# 6                                Bitcoin-Bot     Florida, USA
# 7                     Cryptocurrencies / EUR              NaN
# 8                                    Mikcoin              NaN
# 9                              DeSota Wilson      Atlanta, GA
# 10     @massumeh18 #RefinedWarrior #Activist             NOVA
# 11                             BittrexPrices              NaN
# 12                                   CPUcoin   Cayman Islands
# 13                           One Perspective     Market Place
# ...
